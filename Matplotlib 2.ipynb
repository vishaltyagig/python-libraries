# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# numerical - numerical data...
x = [23,32,24,43]
y = [3,5,2,4]
plt.plot(x,y)

# %% [markdown]
# ### means we can plot numerical - numerical data

# %%
# numerical - categorical data

x = [34,45,23,54]
y = ['A','B','C','D']
plt.plot(x,y)

# %% [markdown]
# ### means we can plot numerical - caterogical data......

# %%
# categorical - categorical data

x = ['A','B','C','D']
Y = ['P','Q','R','S']
plt.plot(x,y)

# %% [markdown]
# ### categorical - categorical data also works.... but we can see that it has no comperison in between data so it plot only a single line.....

# %%
# categorical -boolean value....

x = ['A','B','C','D']
# Y = ['P','Q','R','S']
z = [True,False,False,True]
plt.plot(x,z)

# %% [markdown]
# ### categorical and boolean values are also plot a chart.....

# %%
x = ['A','B','C','D']
# Y = ['P','Q','R','S']
z = [True,True,False,True]
plt.plot(x,z)

# %% [markdown]
# ## permentation.... combination..........

# %%
# numerical - categorical data

x = [34,45,23,54]
y = ['A','B','C','D']
plt.plot(x,y,x)

# %%
# numerical - categorical data

x = [34,45,23,54]
y = ['A','B','C','D']
plt.plot(x,y,y)

# %%
# numerical - categorical data

x = [34,45,23,54]
y = ['A','B','C','D']
plt.plot(x,y,x,y)

# %%
# numerical - categorical data

x = [34,45,23,54]
y = ['A','B','C','D']
plt.plot(x,y)
plt.plot(y,x)

# %%
# numerical - categorical data

x = [34,45,23,54]
y = ['A','B','C','D']
plt.plot(x,y)
plt.plot(x,y)

# %%
# numerical - categorical data

x = [34,45,23,54]
y = ['A','B','C','D']
plt.plot(x,y)
plt.plot(x,x)

# %%
# numerical - categorical data

x = [34,45,23,54]
y = ['A','B','C','D']
plt.plot(x,y)
plt.plot(y,y)

# %%
# numerical - categorical data

x = [34,45,23,54]
y = ['A','B','C','D']
z = ['P','Q','R','S']
plt.plot(x,y)
plt.plot(x,z)

# %%
x = [34,45,23,54]
y = ['A','B','C','D']
z = ['P','Q','R','S']
plt.plot(x,y)
plt.plot(y,z)

# %%
# boolean - boolean

x= np.array([True,True])
y = np.array([False,True])
plt.plot(y,x)

# %% [markdown]
# ### boolean - boolean also plot a chart......

# %%
# boolean - boolean

x= np.array([True,True])
y = np.array([False,True])
plt.plot(x,y)

# %% [markdown]
# ## barchart----->

# %%
x=['Delhi','Jaipur','Noida','Bangalore']
y= [32,30,40,23]
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x=['Delhi','Jaipur','Noida','Bangalore']
y= [32,30,40,23]
plt.barh(x,y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### use barh to move our chart position......  means using barh we convert bar axis......

# %%
# we use two places data


f = ['NY','Sydeny','London','Paris']
f_t = [45,34,27,36]
x=['Delhi','Jaipur','Noida','Bangalore']
y= [32,30,40,23]
plt.bar(x,y)
plt.bar(f,f_t)
# Out:
# <BarContainer object of 4 artists>

# %%
# we use two places data and also define figure size.....

plt.figure(figsize=(16,10))
f = ['NY','Sydeny','London','Paris']
f_t = [45,34,27,36]
x=['Delhi','Jaipur','Noida','Bangalore']
y= [32,30,40,23]
plt.bar(x,y)
plt.bar(f,f_t)
# Out:
# <BarContainer object of 4 artists>

# %%
# pie chart -----> 
a = [45,67,34,29]
myLabel = ['A','B','C','D']
plt.pie(a,labels = myLabel)
# Out:
# ([<matplotlib.patches.Wedge at 0x1ebe298ff70>,
# ...
#  [Text(0.7601688777288659, 0.79507438477946, 'A'),
#   Text(-1.043068995306198, 0.34929510593611074, 'B'),
#   Text(-0.08876544246914145, -1.0964126486972219, 'C'),
#   Text(0.9542693369726455, -0.5471471762823854, 'D')])

# %%
# pie chart -----> 


a = [45,67,34,29]
myLabel = ['A','B','C','D']
plt.pie(a,labels = myLabel,autopct="%0.3f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1ebe2cb0d00>,
# ...
#  [Text(0.7601688777288659, 0.79507438477946, 'A'),
#   Text(-1.043068995306198, 0.34929510593611074, 'B'),
#   Text(-0.08876544246914145, -1.0964126486972219, 'C'),
#   Text(0.9542693369726455, -0.5471471762823854, 'D')],
#  [Text(0.4146375696702904, 0.43367693715243266, '25.714%'),
#   Text(-0.5689467247124717, 0.19052460323787856, '38.286%'),
#   Text(-0.04841751407407715, -0.5980432629257573, '19.429%'),
#   Text(0.5205105474396248, -0.29844391433584655, '16.571%')])

# %% [markdown]
# ### pychart has no axis...
