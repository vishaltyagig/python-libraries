# %%
import pandas as pd

# %%
df = pd.read_csv('D:\CAR DETAILS FROM CAR DEKHO.csv')
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
# 12. how many car is automatic.

df[df['transmission'] == 'Automatic']
# Out:
#                                          name  year  selling_price  km_driven  \
# 12            Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 25            Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 29                 Jaguar XF 2.2 Litre Luxury  2014        1964999      28000
# 30       Mercedes-Benz New C-Class 220 CDI AT  2013        1425000      59000
# 31          Maruti Vitara Brezza ZDi Plus AMT  2018         975000       4500
# ...                                       ...   ...            ...        ...
# 4300  Mercedes-Benz E-Class E250 CDI Elegance  2011         999000      49600
# 4302                       BMW 7 Series 730Ld  2006        1050000      30000
# 4304       Audi Q5 3.0 TDI Quattro Technology  2018        3899000      22000
# 4311                  Toyota Camry Hybrid 2.5  2017        1900000      20118
# 4313       Ford Endeavour 2.2 Titanium AT 4X2  2019        2800000      10000
#
# ...

# %%
df[df['transmission'] == 'Automatic'].sum()
# Out:
# name             Toyota Corolla Altis 1.8 VL CVTToyota Corolla ...
# year                                                        902665
# selling_price                                            630852992
# km_driven                                                 22260584
# fuel             PetrolPetrolDieselDieselDieselDieselDieselDies...
# seller_type      DealerDealerDealerDealerDealerDealerDealerDeal...
# transmission     AutomaticAutomaticAutomaticAutomaticAutomaticA...
# owner            First OwnerFirst OwnerFirst OwnerFirst OwnerFi...
# dtype: object

# %%
# 13. how many car is manul.

df[df['transmission'] == 'Manual']
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df[df['transmission'] == 'Manual'].sum()
# Out:
# name             Maruti 800 ACMaruti Wagon R LXI MinorHyundai V...
# year                                                       7834149
# selling_price                                           1557059541
# km_driven                                                265115890
# fuel             PetrolPetrolDieselPetrolDieselPetrolPetrolPetr...
# seller_type      IndividualIndividualIndividualIndividualIndivi...
# transmission     ManualManualManualManualManualManualManualManu...
# owner            First OwnerFirst OwnerFirst OwnerFirst OwnerSe...
# dtype: object

# %%
# 14. how many cre sold by dealer.

df[df['seller_type'] == 'Dealer']
# Out:
#                                     name  year  selling_price  km_driven  \
# 12       Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 25       Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 26                  Maruti Ciaz VXi Plus  2015         585000      24000
# 27           Hyundai Venue SX Opt Diesel  2019        1195000       5000
# 29            Jaguar XF 2.2 Litre Luxury  2014        1964999      28000
# ...                                  ...   ...            ...        ...
# 4304  Audi Q5 3.0 TDI Quattro Technology  2018        3899000      22000
# 4306              Hyundai i10 Sportz 1.2  2011         235000      43100
# 4309                    Datsun GO Plus T  2017         350000      10171
# 4310     Renault Duster 110PS Diesel RxL  2015         465000      41123
# 4311             Toyota Camry Hybrid 2.5  2017        1900000      20118
#
#         fuel seller_type transmission        owner
# ...

# %%
df[df['seller_type'] == 'Dealer'].sum()
# Out:
# name             Toyota Corolla Altis 1.8 VL CVTToyota Corolla ...
# year                                                       2002115
# selling_price                                            717491953
# km_driven                                                 52510296
# fuel             PetrolPetrolPetrolDieselDieselDieselDieselDies...
# seller_type      DealerDealerDealerDealerDealerDealerDealerDeal...
# transmission     AutomaticAutomaticManualManualAutomaticAutomat...
# owner            First OwnerFirst OwnerFirst OwnerFirst OwnerFi...
# dtype: object

# %%
# 15. how many car sold by Individual

df[df['seller_type'] == 'Individual']
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df[df['seller_type'] == 'Individual'].sum()
# Out:
# name             Maruti 800 ACMaruti Wagon R LXI MinorHyundai V...
# year                                                       6529086
# selling_price                                           1377095580
# km_driven                                                230867552
# fuel             PetrolPetrolDieselPetrolDieselPetrolPetrolPetr...
# seller_type      IndividualIndividualIndividualIndividualIndivi...
# transmission     ManualManualManualManualManualManualManualManu...
# owner            First OwnerFirst OwnerFirst OwnerFirst OwnerSe...
# dtype: object

# %%
# 16. how many car's whose fuel is petrol

df[df['fuel'] == 'Petrol']
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0                    Maruti 800 AC  2007          60000      70000  Petrol
# 1         Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 3           Datsun RediGO T Option  2017         250000      46000  Petrol
# 5             Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6        Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# ...                            ...   ...            ...        ...     ...
# 4326            Honda City 1.5 GXI  2005          65000     150000  Petrol
# 4327                  Tata Nano XM  2015         190000      60000  Petrol
# 4329  Tata Manza Aura Safire BS IV  2010         160000      60000  Petrol
# 4337           Maruti 800 AC BSIII  2009         110000      83000  Petrol
# 4339              Renault KWID RXT  2016         225000      40000  Petrol
#
#      seller_type transmission         owner
# ...

# %%
df[df['fuel'] == 'Petrol'].sum()
# Out:
# name             Maruti 800 ACMaruti Wagon R LXI MinorDatsun Re...
# year                                                       4272741
# selling_price                                            732095612
# km_driven                                                111117989
# fuel             PetrolPetrolPetrolPetrolPetrolPetrolPetrolPetr...
# seller_type      IndividualIndividualIndividualIndividualIndivi...
# transmission     ManualManualManualManualManualManualManualManu...
# owner            First OwnerFirst OwnerFirst OwnerFirst OwnerFi...
# dtype: object

# %%
# 17. how many car's whose fuel is diesel

df[df['fuel'] == 'Diesel']
# Out:
#                                               name  year  selling_price  \
# 2                             Hyundai Verna 1.6 SX  2012         600000
# 4                            Honda Amaze VX i-DTEC  2014         450000
# 15                            Hyundai Verna 1.6 SX  2012         600000
# 17                           Honda Amaze VX i-DTEC  2014         450000
# 27                     Hyundai Venue SX Opt Diesel  2019        1195000
# ...                                            ...   ...            ...
# 4333                               Maruti Ritz VDi  2012         225000
# 4334  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV  2012         600000
# 4335           Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999
# 4336                    Hyundai i20 Magna 1.4 CRDi  2014         409999
# 4338              Hyundai Creta 1.6 CRDi SX Option  2016         865000
#
#       km_driven    fuel seller_type transmission         owner
# ...

# %%
df[df['fuel'] == 'Diesel'].sum()
# Out:
# name             Hyundai Verna 1.6 SXHonda Amaze VX i-DTECHyund...
# year                                                       4335295
# selling_price                                           1440559925
# km_driven                                                171445495
# fuel             DieselDieselDieselDieselDieselDieselDieselDies...
# seller_type      IndividualIndividualIndividualIndividualDealer...
# transmission     ManualManualManualManualManualManualAutomaticA...
# owner            First OwnerSecond OwnerFirst OwnerSecond Owner...
# dtype: object

# %%
# 18. how many car's whose fuel is CNG

df[df['fuel'] == 'CNG']
# Out:
#                                         name  year  selling_price  km_driven  \
# 9                   Maruti Celerio Green VXI  2017         365000      78000
# 22                  Maruti Celerio Green VXI  2017         365000      78000
# 176                  Maruti Alto K10 LXI CNG  2020         282000      40000
# 351              Tata Indigo CS Emax CNG GLX  2014         185000      72000
# 352   Maruti Eeco 5 STR With AC Plus HTR CNG  2012         229999      75000
# 361              Hyundai Santro Xing GLS CNG  2010         130000      98000
# 664          Hyundai Santro Xing GL PLUS CNG  2007          90000      80000
# 712                    Maruti Ertiga VXI CNG  2013         525000      56228
# 824                  Maruti Alto 800 CNG LXI  2012         170000      97000
# 863                   Hyundai Accent GLE CNG  2009         160000      70000
# 1138                  Maruti Wagon R LXI CNG  2013         250000      71000
# ...

# %%
df[df['fuel'] == 'CNG'].sum()
# Out:
# name             Maruti Celerio Green VXIMaruti Celerio Green V...
# year                                                         80539
# selling_price                                             11086997
# km_driven                                                  2689390
# fuel             CNGCNGCNGCNGCNGCNGCNGCNGCNGCNGCNGCNGCNGCNGCNGC...
# seller_type      IndividualIndividualIndividualDealerDealerIndi...
# transmission     ManualManualManualManualManualManualManualManu...
# owner            First OwnerFirst OwnerFirst OwnerFirst OwnerFi...
# dtype: object

# %%
# 19. how many car's whose fuel is eletric
df['fuel']
# Out:
# 0       Petrol
# 1       Petrol
# 2       Diesel
# 3       Petrol
# 4       Diesel
#          ...
# 4335    Diesel
# 4336    Diesel
# 4337    Petrol
# 4338    Diesel
# 4339    Petrol
# Name: fuel, Length: 4340, dtype: object

# %%
df[df['fuel'] == 'eletronic']
# Out:
# Empty DataFrame
# Columns: [name, year, selling_price, km_driven, fuel, seller_type, transmission, owner]
# Index: []

# %%
# 19. which car of petrol is max km_driven

df[df['fuel'] == 'Petrol']
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0                    Maruti 800 AC  2007          60000      70000  Petrol
# 1         Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 3           Datsun RediGO T Option  2017         250000      46000  Petrol
# 5             Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6        Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# ...                            ...   ...            ...        ...     ...
# 4326            Honda City 1.5 GXI  2005          65000     150000  Petrol
# 4327                  Tata Nano XM  2015         190000      60000  Petrol
# 4329  Tata Manza Aura Safire BS IV  2010         160000      60000  Petrol
# 4337           Maruti 800 AC BSIII  2009         110000      83000  Petrol
# 4339              Renault KWID RXT  2016         225000      40000  Petrol
#
#      seller_type transmission         owner
# ...

# %%
df[df['fuel'] == 'Petrol'][['name','km_driven']]
# Out:
#                               name  km_driven
# 0                    Maruti 800 AC      70000
# 1         Maruti Wagon R LXI Minor      50000
# 3           Datsun RediGO T Option      46000
# 5             Maruti Alto LX BSIII     125000
# 6        Hyundai Xcent 1.2 Kappa S      25000
# ...                            ...        ...
# 4326            Honda City 1.5 GXI     150000
# 4327                  Tata Nano XM      60000
# 4329  Tata Manza Aura Safire BS IV      60000
# 4337           Maruti 800 AC BSIII      83000
# 4339              Renault KWID RXT      40000
#
# [2123 rows x 2 columns]

# %%
df[df['fuel'] == 'Petrol'][['name','km_driven']].max()
# Out:
# name         Volkswagen Vento Petrol Highline AT
# km_driven                                 806599
# dtype: object

# %%
# 20. which car of petrol is min km_driven

df[df['fuel'] == 'Petrol'][['name','km_driven']].min()
# Out:
# name         Ambassador Grand 1800 ISZ MPFI PW CL
# km_driven                                     101
# dtype: object

# %%
# 21. which car of Diesel is max km_driven

df[df['fuel'] == 'Diesel'][['name','km_driven']].max()
# Out:
# name         Volvo XC60 D5 Inscription
# km_driven                       560000
# dtype: object

# %%
df[df['fuel'] == 'Diesel'][['name','km_driven']]
# Out:
#                                               name  km_driven
# 2                             Hyundai Verna 1.6 SX     100000
# 4                            Honda Amaze VX i-DTEC     141000
# 15                            Hyundai Verna 1.6 SX     100000
# 17                           Honda Amaze VX i-DTEC     141000
# 27                     Hyundai Venue SX Opt Diesel       5000
# ...                                            ...        ...
# 4333                               Maruti Ritz VDi      90000
# 4334  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV     170000
# 4335           Hyundai i20 Magna 1.4 CRDi (Diesel)      80000
# 4336                    Hyundai i20 Magna 1.4 CRDi      80000
# 4338              Hyundai Creta 1.6 CRDi SX Option      90000
#
# [2153 rows x 2 columns]

# %%
# 22. which car of Diesel is min km_driven

df[df['fuel'] == 'Diesel'][['name','km_driven']].min()
# Out:
# name         Ambassador CLASSIC 1500 DSL AC
# km_driven                                 1
# dtype: object

# %%
# 23. which car of CNG is max km_driven

df[df['fuel'] == 'CNG'][['name','km_driven']].max()
# Out:
# name         Tata Indigo CS Emax CNG GLX
# km_driven                         120000
# dtype: object

# %%
# 24. which car of CNG is min km_driven

df[df['fuel']== 'CNG'][['name','km_driven']].min()
# Out:
# name         Chevrolet Aveo 1.4 CNG
# km_driven                      4000
# dtype: object

# %%
# replace
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.replace('Maruti 800 AC','xyz')
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                                     xyz  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.replace('Maruti 800 AC','xyz',inplace = True )
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                                     xyz  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                                     xyz  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...
