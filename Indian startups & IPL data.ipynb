# %%
import pandas as pd

# %%
df = pd.read_csv('D:\Indian Startup.csv')

# %%
df
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %% [markdown]
# ### basic structure of data.....

# %%
df.info
# Out:
# <bound method DataFrame.info of          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# ...

# %% [markdown]
# ### information of data.....

# %%
df.describe()
# Out:
#            Founded
# count  1208.000000
# mean   2016.655629
# std       4.517364
# min    1963.000000
# 25%    2015.000000
# 50%    2018.000000
# 75%    2020.000000
# max    2021.000000

# %% [markdown]
# ### some description..... but it is not useful to us because this data is not have numerical values

# %%
df.corr()
# Out:
#          Founded
# Founded      1.0

# %% [markdown]
# #### correlation between data....  it has nothing correlation in between data....

# %%
df.sample(15)
# Out:
#          Company/Brand  Founded Headquarters                 Sector  \
# 928          LearnVern   2016.0    Ahmadabad                 EdTech
# 196          kWh Bikes   2020.0    Bangalore             Automotive
# 732      Capital Float   2013.0    Bangalore                FinTech
# 1098        AutomataPi   2017.0        Powai             Automation
# 1039         Stylework   2017.0     Gurugram             Co-working
# 893        Qube Health   2016.0       Mumbai             HealthTech
# 1119        YourPhysio   2020.0       Nagpur             HealthTech
# 424         bitsCrunch   2020.0      Chennai             Blockchain
# 805              Slice   2016.0    Bangalore                FinTech
# 330         PredictiVu   2020.0     Gurugram  Management Consulting
# 818           Chargeup   2019.0    New Delhi       Renewable Energy
# 366           TravClan   2018.0    New Delhi             B2B Travel
# 708           GalaxEye   2020.0      Chennai              SpaceTech
# ...

# %% [markdown]
# ### sample data in our whole data......

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   Headquarters   1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founder/s      1205 non-null   object
#  6   Investor/s     1146 non-null   object
#  7   Amount         1202 non-null   object
#  8   Stage          781 non-null    object
#  9   Date           1209 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 94.6+ KB

# %% [markdown]
# ### it is also information of our data

# %%
df.columns
# Out:
# Index(['Company/Brand', 'Founded', 'Headquarters', 'Sector', 'What it does',
#        'Founder/s', 'Investor/s', 'Amount', 'Stage', 'Date '],
#       dtype='object')

# %% [markdown]
# #### these are all the columns in our data

# %%
# loc & iloc
df.loc[df['Sector'] == 'EdTech']
# Out:
#             Company/Brand  Founded Headquarters  Sector  \
# 186                BYJU'S   2011.0    Bangalore  EdTech
# 192   Sunstone Eduversity   2011.0     Gurugram  EdTech
# 254                Questt   2020.0     Gurugram  EdTech
# 372             EventBeep   2019.0         Pune  EdTech
# 382              Tinkerly   2015.0       Jaipur  EdTech
# ...                   ...      ...          ...     ...
# 1181             Pariksha   2015.0         Pune  EdTech
# 1189          Practically   2018.0    Telangana  EdTech
# 1195                  Kyt   2020.0    Bangalore  EdTech
# 1204             HobSpace   2019.0       Mumbai  EdTech
# 1205              DcodeAI   2020.0    New Delhi  EdTech
#
#                                            What it does  \
# 186   BYJU’S is India's largest ed-tech company and ...
# 192   Sunstone Eduversity is a one-of-its-kind busin...
# 254   Questt is a Free online homework app that lets...
# 372   An inclusive community where students are insp...
# ...

# %% [markdown]
# ### it simply works for location.......

# %%
df
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
df.loc[df['Sector'] == 'EdTech'][0:6]
# Out:
#            Company/Brand  Founded Headquarters  Sector  \
# 186               BYJU'S   2011.0    Bangalore  EdTech
# 192  Sunstone Eduversity   2011.0     Gurugram  EdTech
# 254               Questt   2020.0     Gurugram  EdTech
# 372            EventBeep   2019.0         Pune  EdTech
# 382             Tinkerly   2015.0       Jaipur  EdTech
# 396      Genext Students   2013.0       Mumbai  EdTech
#
#                                           What it does  \
# 186  BYJU’S is India's largest ed-tech company and ...
# 192  Sunstone Eduversity is a one-of-its-kind busin...
# 254  Questt is a Free online homework app that lets...
# 372  An inclusive community where students are insp...
# 382  A STEM learning online-offline solutions provi...
# 396  LIVE online classes with expert tutors for K-1...
#
#                                              Founder/s  \
# 186                   Byju Raveendran, Divya Gokulnath
# 192                       Ashish Munjal, Piyush Nangru
# ...

# %% [markdown]
# ### by using loc we can check particular things.....

# %%
df.iloc

# %%
df.iloc[0:9]
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
# 5       Curefit   2016.0    Bangalore        Health, Wellness & Fitness
# 6     Pocket FM   2018.0    Bangalore                               OTT
# 7   CHARGE+ZONE   2018.0     Vadodara                        Automotive
# 8   PlanetSpark   2017.0     Gurugram              Education Management
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# ...

# %%
df.iloc[0:9].count()
# Out:
# Company/Brand    9
# Founded          9
# Headquarters     9
# Sector           9
# What it does     9
# Founder/s        9
# Investor/s       8
# Amount           9
# Stage            5
# Date             9
# dtype: int64

# %% [markdown]
# ### we can count null values in a specific range.....

# %%
df.iloc[0:].count()
# Out:
# Company/Brand    1209
# Founded          1208
# Headquarters     1208
# Sector           1209
# What it does     1209
# Founder/s        1205
# Investor/s       1146
# Amount           1202
# Stage             781
# Date             1209
# dtype: int64

# %% [markdown]
# ### it is also a method to count null values....... because it told us how much values r available........

# %%
df.loc[df['Sector'] == 'EdTech'].iloc[4:9]
# Out:
#        Company/Brand  Founded Headquarters  Sector  \
# 382         Tinkerly   2015.0       Jaipur  EdTech
# 396  Genext Students   2013.0       Mumbai  EdTech
# 401        OckyPocky   2015.0     Gurugram  EdTech
# 409         Codingal   2020.0    Bangalore  EdTech
# 415           Habbit   2020.0    Bangalore  EdTech
#
#                                           What it does  \
# 382  A STEM learning online-offline solutions provi...
# 396  LIVE online classes with expert tutors for K-1...
# 401  OckyPocky is India's 1st interactive English l...
# 409  Codingal is on a mission to inspire school kid...
# 415  Habbit is online learning community for anyone...
#
#                                              Founder/s  \
# 382  O.P. Godara, Vivek Pathak, Kapil Arya, Sharad ...
# 396                    Ali Asgar Kagzi, Piyush Dhanuka
# 401                                       Amit Agrawal
# 409                     Vivek Prakash, Satyam Baranwal
# ...

# %% [markdown]
# ### we analyse that loc & iloc can work at a same code......

# %% [markdown]
# ## loc = location base search
# ## iloc = index base location search....

# %%
# groupby....

df.groupby(by ='Headquarters').mean()
# Out:
#                         Founded
# Headquarters
# Ahmadabad           2016.500000
# Ahmedabad           2016.000000
# Ambernath           2016.000000
# Andheri             2019.000000
# Bangalore           2017.192488
# ...                         ...
# The Nilgiris        2016.000000
# Thiruvananthapuram  2016.000000
# Trivandrum          2021.000000
# Vadodara            2018.000000
# West Bengal         2019.000000
#
# [70 rows x 1 columns]

# %% [markdown]
# ### mainly groupby works for numerical data and this place it consider founded a num value.......

# %%
df.groupby(by =['Headquarters','Sector']).mean()
# Out:
#                                     Founded
# Headquarters       Sector
# Ahmadabad          AR startup        2016.0
#                    Aeorspace         2017.0
#                    Consulting        2021.0
#                    EdTech            2015.5
#                    Rental            2014.0
# ...                                     ...
# The Nilgiris       Biotechnology     2016.0
# Thiruvananthapuram Human Resources   2016.0
# Trivandrum         E-learning        2021.0
# Vadodara           Automotive        2018.0
# West Bengal        EdTech            2019.0
#
# [579 rows x 1 columns]

# %%
df.groupby(by =['Headquarters','Sector']).mean().iloc[:15]
# Out:
#                                                 Founded
# Headquarters Sector
# Ahmadabad    AR startup                          2016.0
#              Aeorspace                           2017.0
#              Consulting                          2021.0
#              EdTech                              2015.5
#              Rental                              2014.0
# Ahmedabad    Computer Software                   2018.0
#              Consumer Goods                      2014.5
#              Cosmetics                           2019.0
#              Hospital & Health Care              2016.0
#              Housing Marketplace                 2017.0
#              Information Technology & Services   2012.0
#              Legaltech                           2015.0
#              Media                               2018.0
#              Software Startup                    2020.0
# Ambernath    Consumer Goods                      2016.0

# %%
# find the sector which is located in gurgaon.....?

df[df['Headquarters'] == 'Gurgaon'].groupby(by = 'Sector').mean()
# Out:
#                    Founded
# Sector
# B2B Manufacturing   2020.0
# E-learning          2015.0
# EdTech              2019.0
# FinTech             2018.0
# Gaming              2018.0
# Healthcare          2018.0
# Hospitality         2012.0

# %%
df = pd.read_csv('D:\IPL Matches 2008-2020.csv')

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.corr()
# Out:
#                      id  neutral_venue  result_margin
# id             1.000000      -0.292042      -0.010501
# neutral_venue -0.292042       1.000000      -0.006445
# result_margin -0.010501      -0.006445       1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
df[df['city'] == 'Delhi'].groupby(by = 'player_of_match').mean()
# Out:
#                             id  neutral_venue  result_margin
# player_of_match
# A Mishra          8.459972e+05            0.0       7.800000
# A Symonds         4.191600e+05            0.0      11.000000
# AB de Villiers    1.136605e+06            0.0       5.000000
# AM Rahane         9.809650e+05            0.0       7.000000
# AR Patel          7.340190e+05            0.0       4.000000
# AS Rajpoot        1.136582e+06            0.0       4.000000
# BJ Hodge          5.980710e+05            0.0       4.000000
# CH Gayle          5.483720e+05            0.0      21.000000
# CH Morris         9.809450e+05            0.0       1.000000
# CJ Anderson       1.082605e+06            0.0      51.000000
# CR Brathwaite     9.809510e+05            0.0      27.000000
# DA Warner         6.337903e+05            0.0      24.333333
# DJ Hooda          8.297150e+05            0.0       3.000000
# DPMD Jayawardene  3.360220e+05            0.0       6.000000
# ...

# %%
df[df['city'] == 'Delhi'].groupby(by = 'player_of_match').median()
# Out:
#                          id  neutral_venue  result_margin
# player_of_match
# A Mishra           980913.0            0.0            8.0
# A Symonds          419160.0            0.0           11.0
# AB de Villiers    1136605.0            0.0            5.0
# AM Rahane          980965.0            0.0            7.0
# AR Patel           734019.0            0.0            4.0
# AS Rajpoot        1136582.0            0.0            4.0
# BJ Hodge           598071.0            0.0            4.0
# CH Gayle           548372.0            0.0           21.0
# CH Morris          980945.0            0.0            1.0
# CJ Anderson       1082605.0            0.0           51.0
# CR Brathwaite      980951.0            0.0           27.0
# DA Warner          501223.0            0.0           29.0
# DJ Hooda           829715.0            0.0            3.0
# DPMD Jayawardene   336022.0            0.0            6.0
# DR Smith           733981.0            0.0            8.0
# ...

# %%
df[df['city'] == 'Delhi'].groupby(by = 'toss_winner').median()
# Out:
#                                     id  neutral_venue  result_margin
# toss_winner
# Chennai Super Kings           598070.0            0.0           34.0
# Deccan Chargers               460188.0            0.0           11.5
# Delhi Capitals               1176888.5            0.0            6.0
# Delhi Daredevils              548372.0            0.0            8.0
# Kings XI Punjab               573214.0            0.0            5.0
# Kochi Tuskers Kerala          501238.0            0.0            7.0
# Kolkata Knight Riders         980983.0            0.0           24.5
# Mumbai Indians                829747.0            0.0           37.0
# Rajasthan Royals              781845.0            0.0            5.0
# Rising Pune Supergiants       980965.0            0.0            7.0
# Royal Challengers Bangalore   829757.0            0.0           10.0
# Sunrisers Hyderabad           857505.0            0.0            4.5

# %%
df[df['city'] == 'Delhi'].groupby(by = 'toss_winner').mean()
# Out:
#                                        id  neutral_venue  result_margin
# toss_winner
# Chennai Super Kings          6.805384e+05            0.0          36.00
# Deccan Chargers              4.511792e+05            0.0          11.00
# Delhi Capitals               1.176890e+06            0.0           9.00
# Delhi Daredevils             7.115962e+05            0.0          20.80
# Kings XI Punjab              5.954175e+05            0.0          10.75
# Kochi Tuskers Kerala         5.012380e+05            0.0           7.00
# Kolkata Knight Riders        9.820728e+05            0.0          27.50
# Mumbai Indians               8.270910e+05            0.0          26.60
# Rajasthan Royals             8.021158e+05            0.0           5.50
# Rising Pune Supergiants      9.809650e+05            0.0           7.00
# Royal Challengers Bangalore  7.772466e+05            0.0           7.60
# Sunrisers Hyderabad          8.721130e+05            0.0           5.25

# %% [markdown]
# ## append

# %%
df['city'].append(pd.Series(['xyz']))
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7916\3365602900.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df['city'].append(pd.Series(['xyz']))
# 0       Bangalore
# 1      Chandigarh
# 2           Delhi
# 3          Mumbai
# 4         Kolkata
#           ...
# 812         Dubai
# 813     Abu Dhabi
# 814     Abu Dhabi
# 815         Dubai
# 0             xyz
# Length: 817, dtype: object

# %%
df[['city','toss_winner']].append(pd.DataFrame(['xyz']))
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7916\1095306480.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df[['city','toss_winner']].append(pd.DataFrame(['xyz']))
#            city                  toss_winner    0
# 0     Bangalore  Royal Challengers Bangalore  NaN
# 1    Chandigarh          Chennai Super Kings  NaN
# 2         Delhi             Rajasthan Royals  NaN
# 3        Mumbai               Mumbai Indians  NaN
# 4       Kolkata              Deccan Chargers  NaN
# ..          ...                          ...  ...
# 812       Dubai               Delhi Capitals  NaN
# 813   Abu Dhabi          Sunrisers Hyderabad  NaN
# 814   Abu Dhabi               Delhi Capitals  NaN
# 815       Dubai               Delhi Capitals  NaN
# 0           NaN                          NaN  xyz
#
# [817 rows x 3 columns]

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...
