# %% [markdown]
# # PANDAS

# %% [markdown]
# ### mostly of the Data Files are available in
# #### Excel -------->  .xlsx
# #### Csv
# #### jason

# %% [markdown]
# ## Data Types
# ### Numerical = Numbers (Int or float values)
# ### Categorical = category wise Data (object)

# %%
import pandas as pd

# %%
# Make Data 
mydict = {
    'name': ['a','b','c'],
    'age ': (23,67,89)
}

# %% [markdown]
# # Data Frame
# ### Adjust the data in Raw and Column form.....

# %%
# when we convert data in dataframe data will converted raw and column form
df = pd.DataFrame(mydict)
df
# Out:
#   name  age
# 0    a    23
# 1    b    67
# 2    c    89

# %% [markdown]
# ### Store the Data

# %%
# when we store the data we create a csv file and a file will create in our files we check it to go back
df.to_csv('abc.csv')

# %% [markdown]
# ## Read the data
# #### we have many ways to read our data

# %%
# this is the first way to read our data it is a simple path.... Name.... extension 
pd.read_csv('D:\Bengaluru_House_Data.csv')
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# in this  data reading format i m only story data in a variable df.

df = pd.read_csv('D:\Bengaluru_House_Data.csv')

# %%
# when we find any trouble to reading any data then we can use r it is simple present our data in raw format.

df = pd.read_csv(r'D:\Bengaluru_House_Data.csv')

# %%
# in this format of reading our data we only change slash in forward direction in every position

df = pd.read_csv('D:/Bengaluru_House_Data.csv')

# %%
# in this format of reading our data we only use double slash in every position where we use slash

df = pd.read_csv('D:\\Bengaluru_House_Data.csv')

# %%
pd.read_csv('D:\Bengaluru_House_Data.csv')
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df = pd.read_csv('D:\Bengaluru_House_Data.csv')
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...
