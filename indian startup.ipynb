# %%
import pandas as pd

# %%
df = pd.read_csv('D:\Indian Startup.csv')

# %%
df
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   Headquarters   1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founder/s      1205 non-null   object
#  6   Investor/s     1146 non-null   object
#  7   Amount         1202 non-null   object
#  8   Stage          781 non-null    object
#  9   Date           1209 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 94.6+ KB

# %%
df.corr()
# Out:
#          Founded
# Founded      1.0

# %%
df.describe()
# Out:
#            Founded
# count  1208.000000
# mean   2016.655629
# std       4.517364
# min    1963.000000
# 25%    2015.000000
# 50%    2018.000000
# 75%    2020.000000
# max    2021.000000

# %%
df.isnull().sum()
# Out:
# Company/Brand      0
# Founded            1
# Headquarters       1
# Sector             0
# What it does       0
# Founder/s          4
# Investor/s        63
# Amount             7
# Stage            428
# Date               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 504

# %%
df.sample(20)
# Out:
#           Company/Brand  Founded Headquarters  \
# 1082     Express Stores   2019.0     Gurugram
# 536        NimbleBox.ai   2018.0      Chennai
# 422       NeuroPixel.AI   2020.0    Bangalore
# 1081           Pariksha   2015.0         Pune
# 711               MYBYK   2014.0    Ahmadabad
# 737          MentorKart   2018.0    New Delhi
# 1070             Kutuki   2017.0    Bangalore
# 315            EV Plugs   2021.0     Gurugram
# 698             goSTOPS   2014.0    New Delhi
# 264               Groww   2016.0    Bangalore
# 1134        Quali55Care   2018.0       Mumbai
# 249             Tamasha   2020.0       Mumbai
# 62            ByteLearn   2021.0        Noida
# 207             Ishitva   2018.0    Ahmedabad
# 482             Smytten   2015.0     Gurugram
# 634         Sea6 Energy   2010.0    Bangalore
# 971           DusMinute   2017.0    Bangalore
# 993   Five Star Finance   1984.0      Chennai
# 1182            Toothsi   2018.0       Mumbai
# ...

# %%
# mistakes......>

# 1. null values
# 2. amount is cetagorical instead of numerical
# 3. date is in float instead of date time
# 4. amount is having irrelevent data ----> $disclosed

# %%
df.loc[df['Sector'] == 'EdTech'][0:3]
# Out:
#            Company/Brand  Founded Headquarters  Sector  \
# 186               BYJU'S   2011.0    Bangalore  EdTech
# 192  Sunstone Eduversity   2011.0     Gurugram  EdTech
# 254               Questt   2020.0     Gurugram  EdTech
#
#                                           What it does  \
# 186  BYJU’S is India's largest ed-tech company and ...
# 192  Sunstone Eduversity is a one-of-its-kind busin...
# 254  Questt is a Free online homework app that lets...
#
#                             Founder/s  \
# 186  Byju Raveendran, Divya Gokulnath
# 192      Ashish Munjal, Piyush Nangru
# 254      Akhil, Mohsin M, Rohit Pande
#
#                                            Investor/s        Amount     Stage  \
# 186  Oxshott Capital Partners, XN Exponent, Edelweiss  $300,000,000       NaN
# 192                                WestBridge Capital   $28,000,000  Series B
# 254                                   Celesta Capital    $6,750,000  Series A
#
#         Date
# 186  Oct-2021
# ...

# %%
df.iloc
